# %% [markdown]
# <a href="https://colab.research.google.com/github/ihyaulumuddin044/pandas/blob/main/pandas_and_python_for_data_analyst.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "Nama": ["Alice", "Bob", "Charlie", "David", "Eva"],
    "Usia": [25, 30, 35, 40, 45],
    "Kota": ["Jakarta", "Bandung", "Surabaya", "Jakarta", "Bandung"],
    "Pendapatan": [5000000, 6000000, 5500000, 7000000, 6500000],
    "Status": ["Single", "Married", "Married", "Single", "Single"]
}

df = pd.DataFrame(data)
df
# Out:
#       Nama  Usia      Kota  Pendapatan   Status
# 0    Alice    25   Jakarta     5000000   Single
# 1      Bob    30   Bandung     6000000  Married
# 2  Charlie    35  Surabaya     5500000  Married
# 3    David    40   Jakarta     7000000   Single
# 4      Eva    45   Bandung     6500000   Single

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Nama        5 non-null      object
#  1   Usia        5 non-null      int64
#  2   Kota        5 non-null      object
#  3   Pendapatan  5 non-null      int64
#  4   Status      5 non-null      object
# dtypes: int64(2), object(3)
# memory usage: 328.0+ bytes

# %%
rata_rata_usia = df['Usia'].mean()

print('rata2 usia: ',rata_rata_usia)
# Out:
# rata2 usia:  35.0

# %%
jakarta = df[df['Kota'] == 'Jakarta']
jakarta
# Out:
#     Nama  Usia     Kota  Pendapatan  Status
# 0  Alice    25  Jakarta     5000000  Single
# 3  David    40  Jakarta     7000000  Single

# %%
# total pendapatan semua yang single

penghasilan_single = df[df['Status'] == 'Single']['Pendapatan'].sum()
print('total pendapatan single: ',penghasilan_single)
# Out:
# total pendapatan single:  18500000

# %%
# menambahkan kolom baru

df['pajak'] = 10/100 * df['Pendapatan']
df
# Out:
#       Nama  Usia      Kota  Pendapatan   Status     pajak
# 0    Alice    25   Jakarta     5000000   Single  500000.0
# 1      Bob    30   Bandung     6000000  Married  600000.0
# 2  Charlie    35  Surabaya     5500000  Married  550000.0
# 3    David    40   Jakarta     7000000   Single  700000.0
# 4      Eva    45   Bandung     6500000   Single  650000.0
